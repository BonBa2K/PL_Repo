# %%
import pandas as pd

Yu_Gi_Oh_card_data= pd.read_csv("Yu_Gi_Oh_card_data.csv")
Yu_Gi_Oh_card_data.head(5)
# Out:
#                        Name                 Type  Level        Race Attribute  \
# 0             Limit Reverse            Trap Card    NaN  Continuous       NaN
# 1            The 13th Grave       Normal Monster    3.0      Zombie      DARK
# 2           Gem-Enhancement            Trap Card    NaN      Normal       NaN
# 3         Magician's Circle            Trap Card    NaN      Normal       NaN
# 4  Castle of Dark Illusions  Flip Effect Monster    4.0       Fiend      DARK
#
#       ATK     DEF
# 0     NaN     NaN
# 1  1200.0   900.0
# 2     NaN     NaN
# 3     NaN     NaN
# 4   920.0  1930.0

# %%
#鳥獸族的怪獸
Winged_Beast = Yu_Gi_Oh_card_data[Yu_Gi_Oh_card_data['Race'].str.contains("Winged Beast")]
Winged_Beast.head(4)
# Out:
#                                Name            Type  Level          Race  \
# 11           Performapal Springoose  Effect Monster    5.0  Winged Beast
# 106           Prime Material Falcon  Effect Monster    5.0  Winged Beast
# 167  Blackwing - Gale the Whirlwind   Tuner Monster    3.0  Winged Beast
# 170         Gladiator Beast Lanista  Effect Monster    4.0  Winged Beast
#
#     Attribute     ATK     DEF
# 11       WIND  1100.0  2400.0
# 106      WIND  2200.0   800.0
# 167      DARK  1300.0   400.0
# 170      WIND  1800.0  1200.0

# %%
#等級4以下的怪獸
Lv_4 = Yu_Gi_Oh_card_data[Yu_Gi_Oh_card_data['Level'] <4]
Lv_4.head(4)
# Out:
#                Name            Type  Level         Race Attribute     ATK  \
# 1    The 13th Grave  Normal Monster    3.0       Zombie      DARK  1200.0
# 8   Seismic Crasher  Effect Monster    3.0         Rock     EARTH  1400.0
# 12  Miracle Flipper  Effect Monster    2.0  Spellcaster     LIGHT   300.0
# 13        Key Mouse   Tuner Monster    1.0        Beast     EARTH   100.0
#
#       DEF
# 1   900.0
# 8   300.0
# 12  500.0
# 13  100.0

# %%
#鳥獸族怪獸中等級不小於4的怪獸
Target_difference=set(list(Winged_Beast['Name'])).difference(set(list(Lv_4['Name'])))
Yu_Gi_Oh_card_data.loc[Yu_Gi_Oh_card_data.Name.isin(Target_difference)].head(4)
# Out:
#                                    Name             Type  Level          Race  \
# 11               Performapal Springoose   Effect Monster    5.0  Winged Beast
# 106               Prime Material Falcon   Effect Monster    5.0  Winged Beast
# 170             Gladiator Beast Lanista   Effect Monster    4.0  Winged Beast
# 263   Blackwing - Hillen the Tengu-wind    Tuner Monster    5.0  Winged Beast
# 275                             Takuhee   Normal Monster    4.0  Winged Beast
# ...                                 ...              ...    ...           ...
# 6079                         Faith Bird   Normal Monster    4.0  Winged Beast
# 6177                        Harpie Lady   Normal Monster    4.0  Winged Beast
# 6186               Blackwing Armed Wing  Synchro Monster    6.0  Winged Beast
# 6275                  Cyber Harpie Lady   Effect Monster    4.0  Winged Beast
# 6297                  Swift Birdman Joe   Effect Monster    6.0  Winged Beast
#
#      Attribute     ATK     DEF
# 11        WIND  1100.0  2400.0
# 106       WIND  2200.0   800.0
# 170       WIND  1800.0  1200.0
# 263       DARK     0.0  2300.0
# 275       WIND  1450.0  1000.0
# ...        ...     ...     ...
# 6079      WIND  1500.0  1100.0
# 6177      WIND  1300.0  1400.0
# 6186      DARK  2300.0  1000.0
# 6275      WIND  1800.0  1300.0
# 6297      WIND  2300.0  1400.0
#
# [130 rows x 7 columns]

# %%
#鳥獸族怪獸 或 等級小於4的怪獸
Target_union=set(list(Winged_Beast['Name'])).union(set(list(Lv_4['Name'])))
Yu_Gi_Oh_card_data.loc[Yu_Gi_Oh_card_data.Name.isin(Target_union)].head(4)
# Out:
#                       Name            Type  Level          Race Attribute  \
# 1           The 13th Grave  Normal Monster    3.0        Zombie      DARK
# 8          Seismic Crasher  Effect Monster    3.0          Rock     EARTH
# 11  Performapal Springoose  Effect Monster    5.0  Winged Beast      WIND
# 12         Miracle Flipper  Effect Monster    2.0   Spellcaster     LIGHT
#
#        ATK     DEF
# 1   1200.0   900.0
# 8   1400.0   300.0
# 11  1100.0  2400.0
# 12   300.0   500.0

# %%
#鳥獸族怪獸中等級小於4的怪獸
Target_intersection=set(list(Winged_Beast['Name'])).intersection(set(list(Lv_4['Name'])))
Yu_Gi_Oh_card_data.loc[Yu_Gi_Oh_card_data.Name.isin(Target_intersection)].head(4)
# Out:
#                                Name            Type  Level          Race  \
# 167  Blackwing - Gale the Whirlwind   Tuner Monster    3.0  Winged Beast
# 295                    Stealth Bird  Effect Monster    3.0  Winged Beast
# 636                        Niwatori  Normal Monster    3.0  Winged Beast
# 730     Blackwing - Steam the Cloak   Tuner Monster    3.0  Winged Beast
#
#     Attribute     ATK     DEF
# 167      DARK  1300.0   400.0
# 295      DARK   700.0  1700.0
# 636     EARTH   900.0   800.0
# 730      DARK   800.0  1200.0

# %%
#不是鳥獸族怪獸中等級不小於4的怪獸
Target_symmetric_difference=set(list(Winged_Beast['Name'])).symmetric_difference(set(list(Lv_4['Name'])))
Yu_Gi_Oh_card_data.loc[Yu_Gi_Oh_card_data.Name.isin(Target_symmetric_difference)].head(4)
# Out:
#                       Name            Type  Level          Race Attribute  \
# 1           The 13th Grave  Normal Monster    3.0        Zombie      DARK
# 8          Seismic Crasher  Effect Monster    3.0          Rock     EARTH
# 11  Performapal Springoose  Effect Monster    5.0  Winged Beast      WIND
# 12         Miracle Flipper  Effect Monster    2.0   Spellcaster     LIGHT
#
#        ATK     DEF
# 1   1200.0   900.0
# 8   1400.0   300.0
# 11  1100.0  2400.0
# 12   300.0   500.0
